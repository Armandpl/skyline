# %%
import numpy as np
import matplotlib.pyplot as plt

labels = np.loadtxt("../data/centerline_trajectories.txt")

plt.hist(labels[:, -1])
# Out:
# (array([4359.,   65.,   71.,   71.,   74.,   61.,   58.,   69.,   63.,
#         5109.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)
