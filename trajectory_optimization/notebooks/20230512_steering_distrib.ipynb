# %%
import numpy as np
import matplotlib.pyplot as plt

labels = np.loadtxt("../data/rl_trajectories.txt")

plt.hist(labels[:, 4])
plt.title("Steering Command Distribution (rad)")
# Out:
# Text(0.5, 1.0, 'Steering Command Distribution (rad)')

# %%
plt.hist(labels[:, 5])
plt.title("Speed Command Distribution (m/s)")
# Out:
# Text(0.5, 1.0, 'Speed Command Distribution (m/s)')
