# %%
import numpy as np
import matplotlib.pyplot as plt

labels = np.loadtxt("../data/longi_max8_100k/trajectories.txt")

plt.hist(labels[:, 4], bins=60)
plt.title("Steering Command Distribution [-1, 1] = -22.3 deg, +22.3 deg")
# Out:
# Text(0.5, 1.0, 'Steering Command Distribution [-1, 1] = -22.3 deg, +22.3 deg')

# %%
labels[:, 4].max()
# Out:
# 0.9640276432037354

# %%
plt.hist(labels[:, 5])
plt.title("Speed Command Distribution (m/s)")
# Out:
# Text(0.5, 1.0, 'Speed Command Distribution (m/s)')
